# %%
# base model from huggingFace or path to model
base_model = "mistralai/Mistral-7B-Instruct-v0.2"
new_model = "Enlighten_Instruct"

test_path='/content/00/TestData.csv'
train_path='/content/00/TrainData.csv'

# %%
# %%capture # 它会阻止输出被打印到屏幕上，而是将其存储在一个对象中，你可以随后检查这个对象的内容。这对于处理大量输出或只关注代码执行结果而不需要看到所有输出时非常有用
# !pip install -U bitsandbytes
# !pip install transformers==4.36.2
# !pip install -U peft
# !pip install -U accelerate
# !pip install -U trl
# !pip install datasets==2.16.0
# !pip install sentencepiece

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,HfArgumentParser,TrainingArguments,pipeline, logging
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model
import os,torch
from datasets import load_dataset
from trl import SFTTrainer
import pandas as pd
import pyarrow as pa
import pyarrow.dataset as ds
import pandas as pd
from datasets import Dataset
import re

# %% [markdown]
# ### Login to HF

# %%
from google.colab import userdata
secret_hf = userdata.get('HF_TOKEN')
# !huggingface-cli login --token $secret_hf
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### Build Dataset

# %%
df = pd.read_csv(train_path)

# build training dataset with the right format
df['text'] = '<s>[INST]@Enlighten. ' + df['Q'] +'[/INST]'+ df['A'] + '</s>'

# remove columns
df=df.drop(['Q','A','class'],axis=1)

# convert to dataset object
dataset = ds.dataset(pa.Table.from_pandas(df).to_batches())
dataset = Dataset(pa.Table.from_pandas(df))
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 1910
# })

# %% [markdown]
# ### Load the model

# %%
# Load base model
bnb_config = BitsAndBytesConfig(
    load_in_4bit= True,
    bnb_4bit_quant_type= "nf4",
    bnb_4bit_compute_dtype= torch.bfloat16,
    bnb_4bit_use_double_quant= False,
)
model = AutoModelForCausalLM.from_pretrained(
        base_model,
        load_in_4bit=True,
        quantization_config=bnb_config,
        torch_dtype=torch.bfloat16,
        device_map="auto",
        trust_remote_code=True,
)


model.config.use_cache = False # silence the warnings. Please re-enable for inference!
model.config.pretraining_tp = 1
model.gradient_checkpointing_enable()

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
tokenizer.padding_side = 'right'
tokenizer.pad_token = tokenizer.eos_token
tokenizer.add_eos_token = True
tokenizer.bos_token, tokenizer.eos_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# ('<s>', '</s>')

# %%
# count trainging tokens
from transformers import LlamaTokenizer
tokenizer_ = LlamaTokenizer.from_pretrained("cognitivecomputations/dolphin-llama2-7b")
tokens = tokenizer_.tokenize(dataset.to_pandas().to_string())
len(tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# 962734

# %% [markdown]
# ### 开始Fine-Tune

# %%
#Adding the adapters in the layers
model = prepare_model_for_kbit_training(model)
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj","gate_proj"]
)
model = get_peft_model(model, peft_config)

# %%
#Hyperparamter
training_arguments = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=50,
    logging_steps=1,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
)

# %%
# Setting sft parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length= None,
    dataset_text_field="text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing= False,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:223: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/1910 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='478' max='478' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [478/478 56:36, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.542400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.719100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.077000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.766500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.581400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.415200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.145500</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.993900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.975500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.811500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.968000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.661500</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.676600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.487600</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.882100</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.173900</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.797800</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.803100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.675300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.895100</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.782200</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.640900</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.642500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.716100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.890200</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.506800</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.571900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.835900</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.449400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.646400</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.708000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.608000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.338400</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.824400</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.579500</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.562100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.435600</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.493700</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.321400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.481500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.624600</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.465700</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.224500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.725100</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.831900</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.444900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.565100</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.451300</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.659300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.803600</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.956000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.254300</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.430600</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.270000</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.422400</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.074800</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.117900</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.302400</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.479400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.134600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.010500</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.945500</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.342600</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.975100</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.292700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.174900</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.224600</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.154500</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.014800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.203700</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.324600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.161500</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.438300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.150800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.517200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.165000</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.123900</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.954500</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.164100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.017800</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.163500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.270200</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.037900</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.941800</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.265800</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.214800</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.035100</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.324300</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.884700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.018200</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.950200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.353700</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.105400</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.075900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.054100</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.932300</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.020800</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.011000</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.967800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.286900</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.900600</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.012500</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.962800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.273100</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.954600</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.067500</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.986000</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.144000</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.034100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.081400</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.057900</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.038500</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.271000</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.124200</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.999900</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.039000</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.967200</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.197100</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.787800</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.135900</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.074500</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.189100</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.910100</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.909500</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.975200</td>
#     </tr>
#     <tr>
#       <td>126</t
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=478, training_loss=0.9999669882542918, metrics={'train_runtime': 3449.8173, 'train_samples_per_second': 0.554, 'train_steps_per_second': 0.139, 'total_flos': 8899283549110272.0, 'train_loss': 0.9999669882542918, 'epoch': 1.0})

# %% [markdown]
# ### Save and push the adapter to HF

# %%
# Save the fine-tuned model
trainer.model.save_pretrained(new_model)
model.config.use_cache = True
model.eval()
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %%
trainer.model.push_to_hub(new_model)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/369M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/codersan/Enlighten_Instruct/commit/fed7033bf5cf8095e5075686926756affd82b21b', commit_message='Upload model', commit_description='', oid='fed7033bf5cf8095e5075686926756affd82b21b', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# ### Test the model

# %%
logging.set_verbosity(logging.CRITICAL)
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)

# %%
def build_prompt(question):
  prompt=f"<s>[INST]@Enlighten. {question} [/INST]"
  return prompt

# %%
question = "what is the pwoer outage event?"
prompt = build_prompt(question)
result = pipe(prompt)

print(result[0]['generated_text'])
# Out:
# <s>[INST]@Enlighten. what is the pwoer outage event? [/INST]The power outage event is a global event that is triggered when the power is turned off. it is triggered by the level manager when the power is turned off. it is used to update the UI and change the state of the power switches. it is also used to turn off the power switches and turn on the emergency lights. it is a custom event that is defined in the level manager. it is a delegate that takes no arguments and returns nothing. it is called by the level manager when the power is turned off. it is called by the level manager when the power is turned on. it is called by the level manager when the power is turned off. it is called by the level manager when the power is turned on. it is called by the level manager when the power is turned off. it is called by the level manager when the power is turned on.

# %%
df_test=pd.read_csv(test_path)

questionCounter=0
correct=0
promptEnding = "[/INST]"

# this must be >= 2
fail_limit=10

# chain of thought activator, model might run out of output tokens
USE_COT=True

#this comes before the question
testGuide='Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d \n'

for index, row in df_test.iterrows():
    print("#############################")
    questionCounter = questionCounter + 1

    #chain of thought activator
    if USE_COT:
        chainOfThoughtActivator='\nfirst think step by step\n'
    else:
        chainOfThoughtActivator='\n'

    #build the prompt
    question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d'] + chainOfThoughtActivator
    print(question)

    #true answer
    truth=row['Answer']

    #use a loop, if llm stopped before reaching the answer. ask again
    index=-1
    failCounter=0
    while(index==-1):

        #build the prompt
        prompt = build_prompt(question)

        #generate answer
        result = pipe(prompt)
        llmAnswer = result[0]['generated_text']

        #remove our prompt from it
        index = llmAnswer.find(promptEnding)
        llmAnswer = llmAnswer[len(promptEnding)+index:]

        print("LLM Answer:")
        print(llmAnswer)

        #remove spaces
        llmAnswer=llmAnswer.replace(' ','')

        #find the option in response
        index = llmAnswer.find('Answer:')

        #edge case - llm stoped at the worst time
        if(index+len('Answer:')==len(llmAnswer)):
            index=-1

        #update question for the next try. remove chain of thought
        question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d']

        #Don't get stock on a question
        failCounter=failCounter+1
        if failCounter==fail_limit:
            break

    if failCounter==fail_limit:
        continue

    #find and match the option
    next_char = llmAnswer[index+len('Answer:'):][0]
    if next_char in truth:
        correct=correct+1
        print('correct')
    else:
        print('wrong')

    #update accuracy
    accuracy=correct/questionCounter
    print(f"Progress: {questionCounter/len(df_test)}")
    print(f"Accuracy: {accuracy}")
# Out:
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the BeastAttack class do in the Unity project?
# a)Manages player movement
# b)Generates sounds
# c)Manages the beast attack behavior and player hit behavior
# d)Controls the camera
# first think step by step
#
# LLM Answer:
# c)Manages the beast attack behavior and player hit behavior
#
# Answer:c
#
# Explanation:
# The BeastAttack class manages the beast attack behavior and player hit behavior. It is responsible for the beast's attack state and the player's hit state. It also manages the beast's attack animation and the player's hit animation.
#
# Therefore, the BeastAttack class is the best choice for managing the beast attack behavior
# correct
# Progress: 0.0037174721189591076
# Accuracy: 1.0
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the gameObject that uses the BeastAttack.cs script need to have on it?
# a)A Rigidbody
# b)A Collider
# c)A Cinemachine Impulse Source
# d)All of the above
# first think step by step
#
# LLM Answer:
# The gameObject that uses the BeastAttack.cs script needs to have a Rigidbody and a Collider on it.
# Answer:b and a.
#
# Explanation:
# The beast needs to have a Rigidbody to move around and a Collider to detect collisions with other objects.
#
# However, the gameObject that uses the BeastAttack.cs script does not need to have a Cinemachine
# wrong
# Progress: 0.007434944237918215
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the player gets hit while in the beast's Escaping state?
# a)The player is pushed back
# b)The player is pushed back and the beast enters a cooldown state
# c)The player is pushed back and the beast dies
# d)The player is not affected
# first think step by step
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayerThatBeastRuns) navMeshAgent.speed = Constants.BeastFastSpeed;
# else navMeshAgent.speed = normalSpeed;
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayerThatBeastRuns) navMeshAgent.
# LLM Answer:
# Answer:a
#
# The player is pushed back when the beast hits them while in the Escaping state. This is to simulate the impact of the beast's attack.
# wrong
# Progress: 0.011152416356877323
# Accuracy: 0.3333333333333333
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the BeastKillsPlayerSequenceAnimator class?
# a)To control player movement
# b)To manage the beast killing player animation sequence
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# b)To manage the beast killing player animation sequence
#
# Answer:b
# correct
# Progress: 0.01486988847583643
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastKillsPlayerSequenceAnimator class, what does the StartSequence method do?
# a)Finds the farthest destination from the player
# b)Activates and plays the animation sequence
# c)Returns a random destination
# d)Sets the player position
# first think step by step
#
# LLM Answer:
#  ```csharp
# //finds the farthest destination from the player
# var farthestPoint = navMeshAgent.CalculateFarthestPointToPlayer();
# ```
#
# ```csharp
# //activates and plays the animation sequence
# navMeshAgent.enabled = false;
# navMeshAgent.SetDestination(farthestPoint);
# navMeshAgent.enabled = true;
# nav
# LLM Answer:
# b)Activates and plays the animation sequence
#
# Answer:b
# correct
# Progress: 0.01858736059479554
# Accuracy: 0.6
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnRespawnClicked method do in the BeastKillsPlayerSequenceAnimator class?
# a)Deactivates the animation sequence
# b)Teleports the player
# c)Sets the player position
# d)Finds the farthest destination from the player
# first think step by step
#
# LLM Answer:
#  ```csharp
# deactivates the animation sequence
# ```
# Answer:a
#
# ```csharp
# ```
#
# ```csharp
# deactivates the animation sequence
# ```
#
# ```csharp
# deactivates the animation sequence
# ```
#
# ```csharp
# deactivates the animation sequence
# ```
#
#
# correct
# Progress: 0.022304832713754646
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What states can the beast be in, according to the State enum?
# a)Sleep, On Target, Roaming, Escaping, and Bleeding
# b)Sleep, On Target, Roaming, Escaping, and Killing
# c)Sleep, On Target, Roaming, Escaping, and Attacking
# d)Sleep, On Target, Roaming, Escaping, and Stunned
# first think step by step
#
# LLM Answer:
# The beast can be in the following states: Sleep, On Target, Roaming, Escaping, and Bleeding.
# Answer:a.
# wrong
# Progress: 0.026022304832713755
# Accuracy: 0.5714285714285714
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the lights are back on? (event LevelEventHub.OnLightsBackOn)
# a)The beast changes to state Sleep.
# b)The beast changes to state Killing.
# c)The beast changes to state Escaping.
# d)The beast changes to state Roaming.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (state == BeastManager.State.Roaming) {
#   navMeshAgent.speed = normalSpeed;
#   navMeshAgent.enabled = true;
#   navMeshAgent.SetDestination(BeastManager.BeastSpawnOnMeshPos.position);
#   navMeshAgent.enabled = false;
#   navMeshAgent.speed =
# LLM Answer:
# Answer:d
#
# The beast changes to state Roaming.
#
# This is because the beast is now free to roam around the level. It will move to its hiding place and wait for the next power outage.
# wrong
# Progress: 0.02973977695167286
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the _scapingState variable?
# a)To control the beast's movement when it is escaping.
# b)To control the beast's movement when it is sleeping.
# c)To control the beast's movement when it is roaming.
# d)To control the beast's movement when it is on target.
# first think step by step
#
# LLM Answer:
# The _scapingState variable is used to control the beast's movement when it is escaping.
# Answer:a
# correct
# Progress: 0.03345724907063197
# Accuracy: 0.5555555555555556
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the BeastState abstract class in Unity's Beast.States namespace?
# a)To control player movement
# b)To manage some player behavior functionality
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# The BeastState abstract class is a base class for all beast states. It provides a common interface for all beast states, allowing them to share some functionality.
#
# Answer:b
#
# The BeastState abstract class is responsible for managing some player behavior functionality. It provides a common interface for all beast states, allowing them to share some functionality.
#
# Answer:b
#
# The BeastState abstract class is a base
# wrong
# Progress: 0.03717472118959108
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastState class, what is the purpose of the LookAt() method?
# a)To shoot a laser beam in a direction
# b)To slowly turn the head to face a target position
# c)To change the rotation of the entire beast to point it at a position
# d)To fire a projectile at a target
# first think step by step
#
# LLM Answer:
# The LookAt() method is used to slowly turn the beast's head to face a target position.
#
# Answer:b
# correct
# Progress: 0.040892193308550186
# Accuracy: 0.5454545454545454
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method in the BeastState class is responsible for setting up the state's properties and injecting its required parameters?
# a)Init()
# b)Activate()
# c)EnterState()
# d)Start()
# first think step by step
#
# LLM Answer:
#  ```csharp
# c)EnterState()
# ```
#
# Answer:c
#
# The EnterState method is responsible for setting up the state's properties and injecting its required parameters. It is called when the state is activated.
#
# The Init method is used to initialize the state, and the Activate method is used to activate the state. The Start method is used to start the state.
#
# Therefore, the EnterState method
# wrong
# Progress: 0.04460966542750929
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastStateKilling class, what is the purpose of the _timeLeft field?
# a)To store the time since the player was killed
# b)To store the time left until the beast starts attacking
# c)To store the time left before the beast changes state
# d)To store the time left until the beast kills the player
# first think step by step
#
# LLM Answer:
#  ```csharp
# //store the time left before the beast changes state
# private float _timeLeft;
# ```
#
# Answer:c
#
# The _timeLeft field is used to store the time left before the beast changes state.
# correct
# Progress: 0.048327137546468404
# Accuracy: 0.5384615384615384
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the Update() method do in the BeastStateKilling class?
# a)Hides the beast from the player
# b)Makes the beast look at the player and transition to roaming state after a certain time
# c)Makes the beast attack the player
# d)Makes the beast chase the player
# first think step by step
#
# LLM Answer:
# c)Makes the beast attack the player
#
# Answer:c
#
# Explanation:
# The Update() method in the BeastStateKilling class is responsible for updating the state of the beast. In this state, the beast is attacking the player. Therefore, the beast is set to attack the player.
#
# ```csharp
# navMeshAgent.Set
# wrong
# Progress: 0.05204460966542751
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the BeastStateKilling state is activated?
# a)The beast becomes invisible
# b)The beast's movement speed is set to normal
# c)The beast's attack cooldown is reset
# d)The beast's navigation path is reset
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the navMesh destination to the beast's hideout position
# navMeshAgent.SetDestination(beastTransform.position);
# ```
#
# ```csharp
# //set the navMesh destination to the beast's hideout position
# navMeshAgent.SetDestination(beastTransform.position);
# ```
#
# ```csharp
# //set the nav
# LLM Answer:
# Answer:c
#
# The beast's attack cooldown is reset when the BeastStateKilling state is activated. This allows the beast to attack the player immediately.
# wrong
# Progress: 0.055762081784386616
# Accuracy: 0.4666666666666667
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the 'eyeSightDistance' field in BeastStateOnTarget.cs?
# a)It stops other beasts from getting in the player's way.
# b)It sets the player's fast speed.
# c)It defines how far the beast can see.
# d)It determines the player's normal speed.
# first think step by step
#
# LLM Answer:
# c)It defines how far the beast can see.
#
# Explanation:
# The 'eyeSightDistance' field is used to define the maximum distance at which the beast can see the player. If the player is within this distance, the beast can see them. Otherwise, the beast cannot see the player.
#
# Therefore
# LLM Answer:
# c)It defines how far the beast can see.
#
# Answer:c.
# correct
# Progress: 0.05947955390334572
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What will happen if the player is not in the beast's line of sight in BeastStateOnTarget.cs?
# a)The beast will charge at the player.
# b)The beast will continue chasing the player.
# c)The beast will transition to RoamingOnSight state.
# d)The beast will transition to Roaming state.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.path.HasPath) {
#   navMeshAgent.SetDestination(BeastManager.BeastSpawnOnMeshPos.position);
#   return;
# }
# ```
#
# ```csharp
# if (!navMeshAgent.path.HasPath) {
#
# LLM Answer:
# Answer:c
#
# Explanation:
# If the player is not in the beast's line of sight, the beast will transition to the RoamingOnSight state. This state allows the beast to roam around the environment while keeping an eye on the player. Once the player is back in the beast's line of sight, the beast will resume chasing the
# wrong
# Progress: 0.06319702602230483
# Accuracy: 0.47058823529411764
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# When does the beast start running toward the player in BeastStateOnTarget.cs?
# a)When the player is within a certain distance.
# b)When the beast is on cooldown.
# c)When the beast is in RoamingOnSight state.
# d)When the player is not in the beast's line of sight.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayerThatBeastRuns) {
#   navMeshAgent.speed = Constants.BeastFastSpeed;
# }
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance < distanceToPlayerThatBeastRun
# LLM Answer:
# Answer:a. The beast starts running toward the player when the player is within a certain distance.
# correct
# Progress: 0.06691449814126393
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what is the purpose of the `CheckForPlayerInSight()` method?
# a)To check if the player is in the beast's line of sight.
# b)To check if the player is making sound.
# c)To update the beast's current roaming position.
# d)To change the beast's state to OnTarget.
# first think step by step
#
# LLM Answer:
#  ```csharp
# //check if the player is in the beast's line of sight
# if (CheckForPlayerInSight()) {
#   //if the player is in the beast's line of sight, change the beast's state to OnTarget
#   changeState(Beast
# LLM Answer:
# Answer:a. The `CheckForPlayerInSight()` method is used to check if the player is in the beast's line of sight. If the player is in sight, the beast will start chasing the player. Otherwise, the beast will continue roaming.
# correct
# Progress: 0.07063197026022305
# Accuracy: 0.5263157894736842
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what happens when the beast reaches its current roaming point?
# a)It will stay at the point and wait for the player.
# b)It will teleport to a new roaming point.
# c)It will get a new roaming point and start moving towards it.
# d)It will change its state to OnTarget.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance < 0.5f) {
#   navMeshAgent.speed = normalSpeed;
#   navMeshAgent.SetDestination(BeastManager.BeastSpawnOnMeshPos.position);
#   navMeshAgent.speed = fastSpeed;
# LLM Answer:
# Answer:c
#
# Explanation:
# The beast will get a new roaming point and start moving towards it. This is done to make the beast roam around the environment. Once the beast reaches its new roaming point, it will stop moving and wait for the player. This is done to make the beast look like it is roaming around the
# correct
# Progress: 0.07434944237918216
# Accuracy: 0.55
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what does the beast do when it hears the player making sound?
# a)It will change its state to OnTarget.
# b)It will ignore the sound and continue roaming.
# c)It will roam to the player's last heard position.
# d)It will increase the detection angle.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayerThatBeastRuns) {
#   navMeshAgent.speed = Constants.BeastFastSpeed;
# }
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance < distanceToPlayerThatBeastRun
# LLM Answer:
# Answer:a
#
# The beast will change its state to OnTarget when it hears the player making sound. This means that the beast will start chasing the player.
# wrong
# Progress: 0.07806691449814127
# Accuracy: 0.5238095238095238
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, what is the purpose of the Update() method?
# a)To check if the beast has reached its hiding place
# b)To change the beast's state
# c)To make the beast look at the player
# d)To set the beast's destination
# first think step by step
#
# LLM Answer:
#  ```csharp
# //check if the beast has reached its hiding place
# if (navMeshAgent.remainingDistance < distanceToHide) {
#   navMeshAgent.speed = normalSpeed;
#   navMeshAgent.enabled = false;
#   //set the beast's position and rotation to the hideout position and rotation
#   transform.position = hideoutPosition.position;
#
# LLM Answer:
# Answer:a
#
# In BeastStateScaping.cs, the Update() method is used to check if the beast has reached its hiding place. If the beast has reached its hiding place, it will change its state to BeastManager.State.Roaming. Otherwise, it will continue moving towards its hiding place.
# correct
# Progress: 0.08178438661710037
# Accuracy: 0.5454545454545454
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, when does the beast change to the Sleep state?
# a)When the beast reaches its hideout
# b)When the player brings the power back on
# c)When the beast is out
# d)When the player turns off the power
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance > distanceToHideOut) {
#   navMeshAgent.speed = normalSpeed;
#   navMeshAgent.SetDestination(BeastManager.BeastSleepPos.position);
#   return;
# }
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance > distanceToHideOut) {
#
# LLM Answer:
# Answer:a
#
# When the beast reaches its hideout, it changes to the Sleep state. This is to prevent the beast from being active when it is not needed.
# correct
# Progress: 0.08550185873605948
# Accuracy: 0.5652173913043478
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, what happens when the OnStateActivated() method is called?
# a)The beast's destination is set to its hideout position
# b)The beast's speed is set to normal
# c)The beast's state is changed to Sleep
# d)The beast is teleported to its hideout
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the destination to the beast's hideout position
# navMeshAgent.SetDestination(BeastManager.BeastSleepPos.position);
# ```
#
# ```csharp
# //set the speed to normal
# navMeshAgent.speed = Constants.BeastFastSpeed;
# ``
# LLM Answer:
# Answer:a
#
# Explanation:
# The beast's destination is set to its hideout position. This is the first step in the escaping state, where the beast is moving towards its hideout position. Once it reaches the hideout position, it will enter the sleep state.
# correct
# Progress: 0.08921933085501858
# Accuracy: 0.5833333333333334
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Within the BeastStateSleep class, what is the purpose of the OnStateActivated method?
# a)To enable the NavMeshAgent component.
# b)To move the beast to its hideout position.
# c)To set the beast's speed.
# d)To deactivate the beast's gameObject.
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the beast's speed
# navMeshAgent.speed = normalSpeed;
# ```
#
# Answer:a
#
# The OnStateActivated method is called when the beast state is activated. In this case, it sets the beast's speed to the normal speed.
#
# ```csharp
# //
# wrong
# Progress: 0.09293680297397769
# Accuracy: 0.56
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main responsibility of the BeastStateSleep class?
# a)To control the beast's movement.
# b)To manage the beast's attacks.
# c)To handle the beast's sleep state.
# d)To detect when the player is near the beast.
# first think step by step
#
# LLM Answer:
# c)To handle the beast's sleep state.
#
# Answer:c.
#
# Explanation:
# The BeastStateSleep class is responsible for managing the beast's sleep state. It sets the beast's speed to 0, deactivates its collider, and sets the beast's state to sleep. When the beast is activated, its speed is set to normal, its
# correct
# Progress: 0.09665427509293681
# Accuracy: 0.5769230769230769
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which of the following methods is defined in the BeastStateSleep class to handle the beast's behavior when it is activated?
# a)OnStateDeactivated
# b)Update
# c)OnStateActivated
# d)Awake
# first think step by step
#
# LLM Answer:
# The BeastStateSleep class is a state of the beast, so it must have an Update method to handle the beast's behavior when it is activated.
# Answer:b
#
# Explanation:
# The Update method is used to update the state of the beast. In this case, it is used to update the state of the beast when it is activated.
#
# Therefore, the answer is:
# Answer:b
#
# The Be
# wrong
# Progress: 0.10037174721189591
# Accuracy: 0.5555555555555556
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of GlobalEventHub class?
# a)To manage game objects
# b)To allow communication between components without having to reference each other
# c)To handle player input
# d)To store game data
# first think step by step
#
# LLM Answer:
# Answer:b
#
# Explanation:
# The GlobalEventHub class is used to allow communication between components without having to reference each other. This is useful for managing game events and allowing components to listen for specific events.
#
# Therefore, the answer is: Answer:b.
# correct
# Progress: 0.10408921933085502
# Accuracy: 0.5714285714285714
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the OnGameStart event for?
# a)This event is called at the start of the game
# b)This event is called when the player scores points
# c)This event is called when the player dies
# d)This event is called when the player wins the game
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)This event is called at the start of the game
# ```
#
# Answer:a.
#
# The OnGameStart event is called at the start of the game. It is used to initialize the game and set up the game environment.
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csh
# correct
# Progress: 0.10780669144981413
# Accuracy: 0.5862068965517241
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# How do components subscribe to the OnGameStart event?
# a)They add a method to the OnGameStart event delegate
# b)They call the GameStart() method
# c)They add a listener to the OnGameStart event
# d)They set the OnGameStart event to true
# first think step by step
#
# LLM Answer:
#  ```csharp
# They add a listener to the OnGameStart event
# ```
#
# Answer:c
#
# Explanation:
#
# Components can subscribe to the OnGameStart event by adding a method to the OnGameStart event delegate. However, this is not the recommended way to do it. Instead, components should add a listener to the OnGameStart event. This is
# wrong
# Progress: 0.11152416356877323
# Accuracy: 0.5666666666666667
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the LevelEventHub class in LevelEventHub.cs?
# a)To control player movement
# b)To manage some player behavior functionality
# c)To handle player combat actions
# d)To provide a way for components to communicate with each other without referencing each other
# first think step by step
#
# LLM Answer:
# LevelEventHub.cs is a class that provides a way for components to communicate with each other without referencing each other. It acts as a hub for events that can be triggered by any component in the game.
#
# Answer:d
# correct
# Progress: 0.11524163568773234
# Accuracy: 0.5806451612903226
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnPowerCoreInserted method do in LevelEventHub.cs?
# a)Finds the farthest destination from the player
# b)Teleports the player
# c)Returns a random destination
# d)Raises an event when a power core has been inserted into a power station
# first think step by step
#
# LLM Answer:
#  ```csharp
# d)Raises an event when a power core has been inserted into a power station
# ```
#
# Answer:d
#
# The OnPowerCoreInserted method raises an event when a power core has been inserted into a power station. This event is broadcasted to all subscribers, allowing other systems to listen for this event and respond accordingly.
#
# In
# correct
# Progress: 0.11895910780669144
# Accuracy: 0.59375
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnLightGunLightInjected method do in LevelEventHub.cs?
# a)Finds the farthest destination from the player
# b)Teleports the player
# c)Returns a random destination
# d)Raises an event when a new light has been injected into a light gun object
# first think step by step
#
# LLM Answer:
#  ```csharp
# d)Raises an event when a new light has been injected into a light gun object
# ```
#
# Answer:d
#
# Explanation:
# The OnLightGunLightInjected method is called when a new light is injected into a light gun object. It raises an event, which is listened to by other classes,
# correct
# Progress: 0.12267657992565056
# Accuracy: 0.6060606060606061
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of PlayerBehaviourEventHub?
# a)To manage player movement
# b)To communicate between different components
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# Answer:b
#
# Explanation:
# PlayerBehaviourEventHub is a central hub for communication between different components in the player's behavior. It allows components to communicate with each other without having to directly reference each other, making the code more modular and easier to maintain.
# correct
# Progress: 0.12639405204460966
# Accuracy: 0.6176470588235294
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What event is triggered when the player fully grabs an object?
# a)OnPlayerGotHit
# b)OnPlayerGrabbedAnObject
# c)OnPlayerHealthEnded
# d)OnPlayerUnGrabbedAnObject
# first think step by step
#
# LLM Answer:
# b)OnPlayerGrabbedAnObject
#
# Answer:b
#
# Explanation:
# The event OnPlayerGrabbedAnObject is triggered when the player fully grabs an object. This event is used to update the object's position and rotation to match the player's hand.
#
# Therefore, the answer is b.
# correct
# Progress: 0.13011152416356878
# Accuracy: 0.6285714285714286
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which component invokes PlayerRespawned?
# a)GrabbableObjects.cs
# b)PlayerHealthManager.cs
# c)BeastAttack.cs
# d)DeathRespawnManager.cs
# first think step by step
#
# LLM Answer:
# The DeathRespawnManager.cs component invokes PlayerRespawned.
#
# Answer:d
#
# Explanation:
# The DeathRespawnManager.cs component is responsible for managing the death and respawn of the player. When the player dies, the DeathRespawnManager.cs component is invoked, and it calls the PlayerRespawned event. This event is broadcasted to all subscribers, which can include the PlayerHealthManager.cs component. The PlayerHealthManager
# correct
# Progress: 0.13382899628252787
# Accuracy: 0.6388888888888888
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the UiEventHub class?
# a)To handle player movement
# b)To allow communication between components without having to reference each other
# c)To manage some player behavior functionality
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# b)To allow communication between components without having to reference each other
#
# Answer:b
#
# Explanation:
# The UiEventHub class is a central hub for communication between components. It allows components to communicate with each other without having to reference each other directly. This makes the code more modular and easier to maintain.
#
# Therefore, the UiEventHub class is used to manage communication between components, allowing them to interact with each
# correct
# Progress: 0.137546468401487
# Accuracy: 0.6486486486486487
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the MainHint() method do in UiEventHub.cs?
# a)Updates the current objective of the game
# b)Triggers the 'OnMainHint' event
# c)Returns a random destination
# d)Sets the player position
# first think step by step
#
# LLM Answer:
#  ```csharp
# b)Triggers the 'OnMainHint' event
# ```
#
# Answer:b
#
# Explanation:
# The 'MainHint()' method triggers the 'OnMainHint' event, which is a global event that can be listened to by any class in the project. This allows any class to subscribe to this event and respond to it when it is triggered. In this case, it
# correct
# Progress: 0.1412639405204461
# Accuracy: 0.6578947368421053
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which event is used to update the current objective of the game?
# a)OnMainHint
# b)OnCurrentObjectiveUpdate
# c)OnPlayerLookAtInteractable
# d)OnPowerSwitchUpdate
# first think step by step
#
# LLM Answer:
#  ```csharp
# OnCurrentObjectiveUpdate
# ```
#
# Answer:b
#
# Explanation:
# The OnCurrentObjectiveUpdate event is used to update the current objective of the game. It is called by the UiEventHub when the current objective changes. This event is used to update the text of the current objective text in the user interface.
#
# Therefore, the answer is b.
# correct
# Progress: 0.1449814126394052
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In FallenToVoidObjectDestroyer.cs, what is the purpose of the class?
# a)To remove any object that enters the void
# b)To teleport objects to another location
# c)To track the player's position
# d)To set the player's position
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)To remove any object that enters the void
# ```
#
# Explanation:
# The FallenToVoidObjectDestroyer class is responsible for removing any object that enters the void. It is a MonoBehaviour, which means it is a C# class that can be attached to a GameObject. The class is called FallenToVoidObjectDestroyer.cs.
#
# LLM Answer:
# a)To remove any object that enters the void
#
# Answer:a
# correct
# Progress: 0.14869888475836432
# Accuracy: 0.675
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the FallenToVoidObjectDestroyer.cs, what happens when an object enters the "void"?
# a)It is transported to a random location
# b)Its position is reset
# c)It is destroyed
# d)It is teleported to the player
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (other.TryGetComponent<Rigidbody>(out var rb)) {
#   rb.isKinematic = true;
#   rb.useGravity = false;
# }
# ```
#
# The object is made kinematic, meaning it will not be affected by gravity.
#
# ```csharp
# Destroy(other.gameObject);
# ``
# LLM Answer:
#  ```csharp
# c)It is destroyed
# ```
#
# Answer:c
#
# When an object enters the "void", it is destroyed.
#
# This is because the FallenToVoidObjectDestroyer.cs is a trigger collider that is attached to the ground. When an object enters this collider, it is destroyed.
#
# This is a safety mechanism to prevent objects from falling out of the level.
#
# correct
# Progress: 0.1524163568773234
# Accuracy: 0.6829268292682927
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method is responsible for removing an object that falls into the void?
# a)OnTriggerEnter()
# b)Update()
# c)Start()
# d)Awake()
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)OnTriggerEnter()
# ```
#
# Explanation:
#
# The OnTriggerEnter() method is called when something enters the trigger collider. In this case, it is used to remove the object that falls into the void.
#
# Therefore, the answer is a.
#
# Answer:a
# correct
# Progress: 0.15613382899628253
# Accuracy: 0.6904761904761905
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the 'ShoutOnTrigger' field in the PlayerDetector class control?
# a)Whether to destroy the object on trigger
# b)Whether to broadcast an event globally and in the inspector
# c)Whether to call other functions on the object
# d)Whether to add the object to a list of detected objects
# first think step by step
#
# LLM Answer:
#  ```csharp
# b)Whether to broadcast an event globally and in the inspector
# ```
#
# Answer:b
#
# The 'ShoutOnTrigger' field in the PlayerDetector class controls whether to broadcast an event globally and in the inspector when the object is triggered. If this field is enabled, the event
# correct
# Progress: 0.15985130111524162
# Accuracy: 0.6976744186046512
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the PlayerDetector's OnTriggerEnter method is called?
# a)It destroys the object
# b)It broadcasts a global event and invokes a UnityEvent
# c)It teleports the player to a specific location
# d)It saves the object's position
# first think step by step
#
# LLM Answer:
#  ```csharp
# b)It broadcasts a global event and invokes a UnityEvent
# ```
#
# The PlayerDetector's OnTriggerEnter method is called when the player enters the trigger collider. It broadcasts a global event and invokes a UnityEvent, which can be used to trigger other actions in the game.
#
# Answer:b
# correct
# Progress: 0.16356877323420074
# Accuracy: 0.7045454545454546
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the PlayerDetector class?
# a)To detect when an object enters its trigger zone
# b)To manage the player's health
# c)To control the player's movement
# d)To store the player's inventory
# first think step by step
#
# LLM Answer:
# a)To detect when an object enters its trigger zone
# Answer:a
#
# Explanation:
# The PlayerDetector class is used to detect when an object enters its trigger zone. When an object enters the trigger zone, the class triggers an event, which can be used to perform actions such as updating the player's health or unlocking doors.
#
# Therefore, the PlayerDetector class is responsible for detecting when an
# correct
# Progress: 0.16728624535315986
# Accuracy: 0.7111111111111111
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the SimpleLight class?
# a)To control the intensity of lights.
# b)To manage the range of lights.
# c)To toggle lights on and off.
# d)To change the color of lights.
# first think step by step
#
# LLM Answer:
# The SimpleLight class is responsible for managing the light source, controlling its intensity, and changing its color.
#
# Answer:d
#
# The SimpleLight class is used to control the light source, including its intensity and color. It can be used to turn the light on or off, and to change its color.
#
# Answer:d
#
# The SimpleLight class is used to manage the light source, including its intensity and color. It can be used to
# wrong
# Progress: 0.17100371747211895
# Accuracy: 0.6956521739130435
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is a complex light in the context of SimpleLight?
# a)A light with multiple sources.
# b)A light that emits multiple colors.
# c)A light that is attached to a child object.
# d)A light that is brighter than a simple light.
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)A light with multiple sources.
# ```
#
# ```csharp
# //a light with multiple sources
# public Light[] _additionalLights { get; private set; }
# ```
#
# ```csharp
# //a light that is attached to a child object
# public Transform child { get; private set; }
# ```
#
#
# LLM Answer:
# Answer:a
#
# A complex light is a light that has multiple sources, meaning it can have multiple materials or textures applied to it. This allows for more complex lighting effects.
# wrong
# Progress: 0.17472118959107807
# Accuracy: 0.6808510638297872
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the TurnOn method do in SimpleLight?
# a)Turns the light off.
# b)Sets the light's color.
# c)Turns the light on and sets its color.
# d)Sets the light's intensity.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (_meshRenderer.sharedMaterial!= materials.Off) {
#   _meshRenderer.sharedMaterial = materials.Off;
#   _meshRenderer.enabled = false;
# }
# ```
#
# ```csharp
# if (_meshRenderer.sharedMaterial!= materials.On) {
#   _meshRenderer.sharedMaterial = materials.On;
#   _meshRenderer.enabled = true;
# }
# LLM Answer:
# Answer:c
#
# The TurnOn method turns the light on and sets its color. It also sets the material of the light to the 'On' material, which has an emissive color. This makes the light glow.
#
# The TurnOff method does the opposite: it turns the light off and sets its material to the 'Off' material, which has no emissive color. This turns off the light.
#
# The SetColor method sets the light's color
# correct
# Progress: 0.17843866171003717
# Accuracy: 0.6875
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the KitsController class?
# a)To control player movement and animation
# b)To manage player behavior
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# The KitsController class is responsible for managing the player's movement and animation. It is a MonoBehaviour class, which means it can be attached to a GameObject in the Unity editor.
#
# Answer:a
# correct
# Progress: 0.1821561338289963
# Accuracy: 0.6938775510204082
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method is used to make Kits run to a random destination?
# a)GoThere()
# b)UpdateAnimator()
# c)LightsOut()
# d)LightsBackOn()
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)GoThere()
# ```
#
# Answer:a
#
# Explanation:
#
# The GoThere() method is used to make Kits run to a random destination. It sets the destination of the navMeshAgent to a random position within the navMeshAgent's reach.
#
# Therefore, the answer is a.
#
# ```csharp
# Answer:a
# ```
#
# ```csharp
# correct
# Progress: 0.18587360594795538
# Accuracy: 0.7
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the KitsController class do when the power goes out?
# a)Start running to a random destination
# b)Light up Kits mask
# c)Stop moving
# d)Turn off Kits mask
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.enabled) navMeshAgent.enabled = false;
# ```
#
# ```csharp
# if (navMeshAgent.enabled) navMeshAgent.enabled = true;
# ```
#
# ```csharp
# if (navMeshAgent.enabled) navMeshAgent.enabled = false;
# ```
#
# ```csharp
# if (navMeshAgent.enabled) navMeshAgent.enabled
# LLM Answer:
# Answer:c
#
# When the power goes out, the KitsController class stops moving. This prevents the Kits from moving around in the dark. This is a safety feature to prevent the Kits from getting lost or disoriented in the dark.
#
# When the power comes back on, the KitsController class resumes moving. This allows the Kits to resume its normal behavior.
#
# Therefore, the answer is: Answer:c. The KitsController class stops moving when the power goes out.
# wrong
# Progress: 0.1895910780669145
# Accuracy: 0.6862745098039216
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the Level.LevelLightsManager class?
# a)To control player movement.
# b)To manage lights during a power outage and when the power is restored.
# c)To handle player combat actions.
# d)To store references to key player components.
# first think step by step
#
# LLM Answer:
# The Level.LevelLightsManager class is responsible for managing lights during a power outage and when the power is restored.
#
# Answer:b
# correct
# Progress: 0.19330855018587362
# Accuracy: 0.6923076923076923
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the emergencyLights field in Level.LevelLightsManager?
# a)A collection of lights that stay on during a power outage.
# b)A variable that tells you if the lights are on or off.
# c)A manager for the lights in the level.
# d)A list of all the lights in the level.
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)A collection of lights that stay on during a power outage.
# ```
#
# ```csharp
# Answer:a
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# correct
# Progress: 0.1970260223048327
# Accuracy: 0.6981132075471698
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnPowerSwitchActivated method do in Level.LevelLightsManager?
# a)Turns off the lights.
# b)Turns on the lights.
# c)Increments the count of activated power switches.
# d)Decrements the count of activated power switches.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (powerSwitchCount == 0) {
#   //turn off the lights
#   levelLights.enabled = false;
#   //set the material of the light material to the off material
#   levelLightsMaterial.SetFloat("_MyEmissiveIntensity", Constants.LightGunLightEmissionAmountOff);
#   //set the material
# LLM Answer:
# Answer:c.
#
# The OnPowerSwitchActivated method increments the count of activated power switches. This is done when a power switch is activated.
#
# When a power switch is activated, the OnPowerSwitchActivated method is called. This method increments the count of activated power switches and updates the UI to show the new count.
#
# If all power switches are activated, the lights are turned on
# correct
# Progress: 0.20074349442379183
# Accuracy: 0.7037037037037037
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In LevelManager.cs, what is the purpose of the mainMenuCameraTransform field?
# a)To set the camera position for the main menu scene.
# b)To set the camera position for the player respawn point.
# c)To set the camera position for the level start point.
# d)To set the camera position for the beast spawn point.
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)To set the camera position for the main menu scene.
# ```
#
# Answer:a
# correct
# Progress: 0.20446096654275092
# Accuracy: 0.7090909090909091
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the FinishedAndExitedLevel() method do in LevelManager.cs?
# a)Calculates the time to beat the level and saves it.
# b)Unloads the current level and loads the next one.
# c)Locks the main door to prevent the player from re-entering the level.
# d)All of the above
# first think step by step
#
# LLM Answer:
#  ```csharp
# //calculate the time to beat the level and save it
# var timeToBeat = levelTime;
# PlayerPrefs.SetFloat("Level" + levelNumber + "_Time", timeToBeat);
#
# //unload the current level and load the next one
# levelManager.UnloadLevel(level
# LLM Answer:
# Answer:b
#
# Explanation:
# The FinishedAndExitedLevel() method unloads the current level and loads the next one. This is done to prepare for the next level.
#
# It is important to note that this method is called by the LevelLightsManager.cs when the power is turned back on.
#
# Therefore, the FinishedAnd
# wrong
# Progress: 0.20817843866171004
# Accuracy: 0.6964285714285714
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when a player detector is triggered in LevelManager.cs?
# a)The player enters the next level.
# b)The player exits the current level.
# c)The player respawns at the last checkpoint.
# d)The player's health is restored.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (id == 0) {
#   //player is at the start of the level, unlock the main door and activate the level
#   unlockMainDoor();
#   activateLevel(levelNumber);
# }
# ```
#
# ```csharp
# if (id == 1) {
#   //player is at the end of the level, unlock the main door
# LLM Answer:
# Answer:a
#
# When a player detector is triggered in LevelManager.cs, the player enters the next level. This is typically used to move the player to the next level when they reach the end of the current level.
# wrong
# Progress: 0.21189591078066913
# ...
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the SingletonMonoBehaviour.cs class provide?
# a)A custom implementation of the singleton pattern
# b)A way to manage multiple instances of the same class
# c)A way to store and access global variables
# d)A way to create abstract classes
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)A custom implementation of the singleton pattern
# ```
#
# The SingletonMonoBehaviour.cs class provides a custom implementation of the singleton pattern, which ensures that there is only one instance of the class in the game.
# LLM Answer:
# Answer:a. The SingletonMonoBehaviour.cs class provides a custom implementation of the singleton pattern, which ensures that there is only one instance of the class in the game.
# correct
# Progress: 0.9219330855018587
# Accuracy: 0.6935483870967742
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# How is the Singleton instance set in SingletonMonoBehaviour.cs?
# a)Through the Awake method
# b)Through the Start method
# c)Through the Update method
# d)Through the FixedUpdate method
# first think step by step
#
# LLM Answer:
#  ```csharp
# Awake()
# ```
#
# The Awake method is called when the game object is instantiated. It is used to initialize the game object and its components. In this case, it is used to set the Singleton instance.
#
# Answer:a. The Singleton instance is set through the Awake method.
# correct
# Progress: 0.9256505576208178
# Accuracy: 0.6947791164658634
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens if there is already an instance of a Singleton class when trying to create another one?
# a)The new instance is destroyed
# b)The old instance is destroyed
# c)Both instances are destroyed
# d)An error is logged in the console
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (instance) {
#   Destroy(gameObject);
#   return;
# }
# ```
#
#  ```csharp
# instance = this as T;
# ```
#
#  ```csharp
# if (instance) {
#   Destroy(gameObject);
#   return;
# }
# ```
#
#  ```csharp
# instance = this as T;
# ```
# LLM Answer:
# Answer:c
#
# Explanation:
# Both instances are destroyed to prevent conflicts and ensure that there is only one instance of the Singleton class.
# wrong
# Progress: 0.929368029739777
# Accuracy: 0.692
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the Normalize method do in Utils.cs?
# a)Inverts the color components
# b)Converts a color to grayscale
# c)Adjusts a color to make its brightest component equal to 1
# d)Scales a color by a random factor
# first think step by step
#
# LLM Answer:
#  ```csharp
# c)Adjusts a color to make its brightest component equal to 1
# ```
#
# Answer:c
#
# The Normalize method scales a color by a factor of 1/maximum component value, making the brightest component equal to 1. This is useful for comparing colors or setting color values to a specific maximum value.
# correct
# Progress: 0.9330855018587361
# Accuracy: 0.6932270916334662
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In FlashLightUiManager.cs what is the purpose of the FlashLightUiManager class?
# a)To control player movement
# b)To manage the flash light UI
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# b)To manage the flash light UI
#
# Answer:b
#
# Explanation:
# The FlashLightUiManager class is responsible for managing the flash light UI, which includes updating the UI to show the battery level of the flash light.
# correct
# Progress: 0.9368029739776952
# Accuracy: 0.6944444444444444
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the Update() method do in FlashLightUiManager.cs?
# a)Updates the UI according to the battery level
# b)Teleports the player
# c)Returns a random destination
# d)Sets the player position
# first think step by step
#
# LLM Answer:
#  ```csharp
# UpdateUi();
# ```
#
# Answer:a
#
# The UpdateUi() method is called to update the UI according to the battery level.
# correct
# Progress: 0.9405204460966543
# Accuracy: 0.6956521739130435
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which component is updated to show the battery level?
# a)Text
# b)Slider
# c)Image
# d)Button
# first think step by step
#
# LLM Answer:
#  ```csharp
# c)Image
# ```
#
# The battery level is shown by changing the color of the image.
#
# Answer:c
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
# ```
#
# ```csharp
#
# correct
# Progress: 0.9442379182156134
# Accuracy: 0.6968503937007874
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What are the types of the fullscreen effects managed by FullScreenEffectsManager?
# a)Low on health and teleport
# b)Low on health and slow motion
# c)Teleport and slow motion
# d)Low on health and poisoning
# first think step by step
#
# LLM Answer:
#  ```csharp
# FullScreenEffectsManager manages the following fullscreen effects:
# - Low on health and teleport
# - Low on health and slow motion
# - Teleport and slow motion
# - Low on health and poisoning
# ```
#
# Answer:c,d.
#
# ```csharp
# FullScreenEffectsManager manages the following fullscreen effects:
# - Low on health and teleport
# - Low on health and
# wrong
# Progress: 0.9479553903345725
# Accuracy: 0.6941176470588235
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does FullScreenEffectsManager.cs do when HealthLowHealthEffect() is called?
# a)Hides the low-health effect
# b)Animates intensity of the low-health effect
# c)Resets the low-health effect
# d)Shows the teleport effect
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the material property
# material.SetFloat("_MyEmissiveIntensity", 0);
# //animate the intensity of the effect
# DOTween.Sequence().AppendInterval(0.5f).OnComplete((() => {
#   //set the material property
#   material.SetFloat("_MyEmissiveIntensity", 1);
#   //animate
# LLM Answer:
# b)Animates intensity of the low-health effect
#
# Answer:b
# correct
# Progress: 0.9516728624535316
# Accuracy: 0.6953125
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In FullScreenEffectsManager.cs, what is the name of the method called when a player teleports?
# a)Teleportation()
# b)Teleport()
# c)PlayerTeleport()
# d)TeleportPlayer()
# first think step by step
#
# LLM Answer:
#  ```csharp
# PlayerTeleport()
# ```
#
# Answer:c
#
# ```csharp
# public void PlayerTeleport() => fullScreenEffectsManager.PlayerTeleport();
# ```
#
# ```csharp
# public void PlayerTeleport() => fullScreenEffectsManager.PlayerTeleport();
# ```
#
# ```csharp
# public void PlayerTeleport() => fullScreenEffectsManager.PlayerTele
# wrong
# Progress: 0.9553903345724907
# Accuracy: 0.6926070038910506
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the role of GamePlayCanvasManager in the script?
# a)To manage the activation and deactivation of gameplay canvas elements
# b)To handle player movement
# c)To store references to key player components
# d)To control the player's combat actions
# first think step by step
#
# LLM Answer:
# a)To manage the activation and deactivation of gameplay canvas elements
#
# Answer:a
# correct
# Progress: 0.9591078066914498
# Accuracy: 0.6937984496124031
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What method is used to deactivate the gameplay UI in GamePlayCanvasManager?
# a)EnableGameplayUi
# b)DisableGameplayUi
# c)SetGameplayUiActive
# d)ToggleGameplayUi
# first think step by step
#
# LLM Answer:
#  ```csharp
# DisableGameplayUi
# ```
#
# Answer:b
#
# Explanation:
# The method used to deactivate the gameplay UI in GamePlayCanvasManager is DisableGameplayUi.
#
# Therefore, the answer is b.
#
# ```csharp
# DisableGameplayUi
# ```
#
# Answer:b
#
# Explanation:
# The method used to deactivate the
# correct
# Progress: 0.9628252788104089
# Accuracy: 0.694980694980695
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the SingletonMonoBehaviour<GamePlayCanvasManager> base class?
# a)To ensure there is only one instance of GamePlayCanvasManager active at a time
# b)To facilitate communication between different GamePlayCanvasManager instances
# c)To provide a shared interface for accessing GamePlayCanvasManager functionality
# d)To allow GamePlayCanvasManager to interact with other components in the scene
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)To ensure there is only one instance of GamePlayCanvasManager active at a time
# ```
#
# Answer:a
#
# Explanation:
# The SingletonMonoBehaviour<GamePlayCanvasManager> base class is used
# correct
# Progress: 0.966542750929368
# Accuracy: 0.6961538461538461
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the UIBeastManager class do in Unity?
# a)It controls lighting
# b)It manages UI elements for the player's beast
# c)It handles player combat
# d)It manages the camera view
# first think step by step
#
# LLM Answer:
# b)It manages UI elements for the player's beast
#
# Answer:b
#
# Explanation:
# The UIBeastManager class is responsible for managing the UI elements related to the beast. It updates the UI to show the beast's state, such as its health and state.
#
# Therefore, the answer is b.
# correct
# Progress: 0.9702602230483272
# Accuracy: 0.6973180076628352
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the OnEnable() method in UIBeastManager.cs?
# a)To subscribe to events
# b)To start the game
# c)To load the next level
# d)To stop the game
# first think step by step
#
# LLM Answer:
#  ```csharp
# a)To subscribe to events
# ```
#
# Answer:a
#
# Explanation:
# The OnEnable() method is used to subscribe to events, allowing the UIBeastManager to listen for changes in the beast's state. This enables the UI to update accordingly.
# correct
# Progress: 0.9739776951672863
# Accuracy: 0.6984732824427481
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the OnDisable() method in UIBeastManager.cs used for?
# a)To restart the game
# b)To unsubscribe from events
# c)To save the game
# d)To pause the game
# first think step by step
#
# LLM Answer:
#  ```csharp
# //unsubscribe from events
# beastTransform.gameObject.SetActive(false);
# ```
#
# Answer:b. The OnDisable() method is used to unsubscribe from events, which prevents the beast from listening for changes in the player's position. This ensures that the beast does not react to the player's movements when it is not active.
# correct
# Progress: 0.9776951672862454
# Accuracy: 0.6996197718631179
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the UICurrentObjectivesManager class manage on the UI?
# a)Player movement
# b)Enemy behaviour
# c)Story progression
# d)Current objectives messages
# first think step by step
#
# LLM Answer:
# The UICurrentObjectivesManager class manages the current objectives messages on the UI.
#
# Answer:d.
#
# Explanation:
# The UICurrentObjectivesManager class is responsible for displaying the current objectives messages on the UI. It listens to events related to the game state and updates the UI accordingly.
#
# Therefore, the answer is d.
# correct
# Progress: 0.9814126394052045
# Accuracy: 0.7007575757575758
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the responsibility of the CurrentObjectiveUpdate function in UICurrentObjectivesManager.cs?
# a)Updating the current objective UI element
# b)Hiding the UI element
# c)Starting the game
# d)Unsubscribing from events
# first think step by step
#
# LLM Answer:
#  ```csharp
# //update the UI
# UpdateCurrentObjective(message);
# ```
#
# Answer:a
#
# The CurrentObjectiveUpdate function is responsible for updating the current objective UI element. It takes a message as a parameter and updates the text of the UI element to display the message.
# correct
# Progress: 0.9851301115241635
# Accuracy: 0.7018867924528301
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which event does the UICurrentObjectivesManager subscribe to in order to update the current objective UI?
# a)UiEventHub.OnGameStart
# b)UiEventHub.OnEnemyKilled
# c)UiEventHub.OnPlayerDeath
# d)UiEventHub.OnCurrentObjectiveUpdate
# first think step by step
#
# LLM Answer:
#  ```csharp
# UiEventHub.OnCurrentObjectiveUpdate
# ```
#
# Answer:d
#
# Explanation:
# The UiEventHub.OnCurrentObjectiveUpdate event is used to update the current objective UI. This event is triggered when the current objective changes. The UICurrentObjectivesManager subscribes to this event
# correct
# Progress: 0.9888475836431226
# Accuracy: 0.7030075187969925
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does UiHintManager do?
# a)Displays hints to the player.
# b)Manages player inventory.
# c)Controls player movement.
# d)Calculates the player's score.
# first think step by step
#
# LLM Answer:
#  ```csharp
# UiHintManager.cs is responsible for displaying hints to the player.
# ```
# Answer:a.
#
# ```csharp
# UiHintManager.cs is a class that manages the hints displayed to the player.
# ```
# Answer:a.
#
# ```csharp
# UiHintManager.cs is a class that manages the hints displayed to the player. It is responsible for
# correct
# Progress: 0.9925650557620818
# Accuracy: 0.704119850187266
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when OnMainHint is called?
# a)The main hint text is updated.
# b)The player's score is increased.
# c)The game is paused.
# d)The player's health is restored.
# first think step by step
#
# LLM Answer:
#  ```csharp
# //update the main hint text
# UpdateMainHint();
# ```
#
# ```csharp
# //update the main hint text
# UpdateMainHint();
# ```
#
# Answer:a. The main hint text is updated.
# correct
# Progress: 0.9962825278810409
# Accuracy: 0.7052238805970149
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the mainHintText field?
# a)To store the player's name.
# b)To store the current level.
# c)To display hints to the player.
# d)To store the game's high score.
# first think step by step
#
# LLM Answer:
# c)To display hints to the player.
#
# Explanation:
# The mainHintText field is used to store the text that will be displayed in the UI as hints to the player. This text can be changed dynamically based on the game's state.
#
# Answer:c.
# correct
# Progress: 1.0
# Accuracy: 0.7063197026022305

# %% [markdown]
# --------------------------
